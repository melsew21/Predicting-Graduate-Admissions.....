# %% [markdown]
#           JINKA UNIVERSITY
#
#         College Of Natural And Computitional Science
#         Department Of Computer Science
#         Course Name: Real Time And Embedded System
#         Course Code: CoSc3026
#         Instructor NAME: TEMESGEN A
#        MELSEW ADANE................14358/14
#
#
#        Project Title:Predicting-Graduate-Admissions
#
#          ## Documentation and Definition of all project:-
#
# 1.	Select Title Define your title: Predicting Graduate Admission Decisions using Machine Learning
# 2.	Problem Definition
# •	Problem Statement: Regression Predicting the likelihood of admission for prospective graduate students based on their application materials.
# 3.	Data
# •	Sourcing: Gather data from university admission records, including past applicant information such as GPA, GRE scores, TOEFL scores, Statement of Purpose, Letters of Recommendation, etc.
# •	Defining Parameters: Identify relevant parameters for predicting admission decisions.
# •	Expert Consultation: Consult with admission officers or experts in the field of education to understand the criteria and factors influencing admission decisions.
#     * Parameters:
#     * GRE Score
#     * TOEFL Score
#     * University Rating
#     * SOP Strength
#     * LOR Strength
#     * CGPA
#     * Research Experience
#     * Expert Consultation: Contacted an admissions officer for insights into the admission process.
#
# 4.	Evaluation
# •	Define Evaluation Metric: Mean Absolute Error (MAE) or Root Mean Squared Error (RMSE) to measure the prediction accuracy of the model.
# 5.	Features
#  •Create a Data Dictionary: Document each feature in the dataset including its name, description, data type, and possible values.
#  * Created a data dictionary to document the features and their meaning.
#  * Analyzed correlations between features and the target variable (admission status).
#  * Removed irrelevant or highly correlated features.
#
# 6.	Preparing the Tools
#     # Importing the required libraries
#     import pandas as pd
#     import numpy as np
#     import matplotlib.pyplot as plt
#     import seaborn as sns
#     import warnings
# •	Consolidate libraries: Import necessary libraries such as Pandas, NumPy, Matplotlib, seaborn, and Scikit-learn.
# 7.	Load Data
#     df = pd.read_csv('graduate_admissions.csv')
# 8.	Data Exploration (EDA)
#    •	Identify questions: Determine the primary questions to be addressed with the data.
#    •	Data Types: Identify different types of data (numerical, categorical) and treat them accordingly.
#    •	Handle Missing Data: Identify missing values and decide on appropriate strategies for handling them.
#    •	Compare Columns: Analyze relationships between variables and their correlation with the target variable.
#    •	Feature Engineering: Explore opportunities to add, modify, or remove features to enhance the predictive power of the model.
#    * Visualized distributions of features using histograms and scatter plots.
#    * Identified missing values and handled them using imputation techniques.
#    * Computed descriptive statistics to understand the data better
# 9.	Modelling
#   * Features and Labels: Separated the data into features (independent variables) and labels (dependent variable).
#   * Training and Test Split: Split the data into training and test sets (80/20 split).
#   * Model Choices: Evaluated different classification models (Logistic Regression, Decision Tree, Random Forest).
#   * Model Comparison: Selected Logistic Regression based on its performance on the training and validation sets.
#   * Hyperparameter Tuning and Cross-Validation: Optimized hyperparameters using cross-validation to improve model performance.
#   •	Define features and labels.
#   •	Split data into training and testing sets.
#   •	Choose appropriate models for regression (e.g., Linear Regression, Random Forest Regression).
#   •	Compare performance of different models.
#   •	Tune hyperparameters and perform cross-validation.
# 10.	Evaluating the Model
#
#   * Classification Report: Generated a classification report to assess model accuracy, precision, recall, and F1-score.
#   * ROC Curve and AUC Score: Plotted the receiver operating characteristic (ROC) curve and calculated the area under the curve (AUC) to evaluate model discrimination ability.
#   * Confusion Matrix: Visualized the confusion matrix to analyze model predictions.
#   •	Calculate additional evaluation metrics beyond default score(), such as MAE, RMSE.
# 11.	Feature Importance
#    *Used the feature_importances_ attribute of the trained model to determine the relative importance of each feature in making predictions.
#    •Determine which features contribute most to the admission decision prediction.
# 12.	Experimentation
#
#   * Tried different feature scaling techniques to improve model performance.
#   * Added additional features to the model to capture more information.
#   * Re-evaluated model performance after each iteration.
#   •	Assess whether the model meets the defined evaluation metric.
#   •	If not, explore alternative options such as collecting more data, trying different models, or improving the current model.
# 13.	Save the Model
#    * Serialized the trained model using Python's pickle module to save it for future use.
#    •Export the trained model for future use and sharing with others.

# %%
# Importing the required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('Admission_Predict_Ver1.1.csv')

# %%
df = data.copy()
df.tail(20)
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 480         481        321          102                  3  3.5   4.0  9.01
# 481         482        323          107                  4  3.0   2.5  8.48
# 482         483        328          113                  4  4.0   2.5  8.77
# 483         484        304          103                  5  5.0   3.0  7.92
# 484         485        317          106                  3  3.5   3.0  7.89
# 485         486        311          101                  2  2.5   3.5  8.34
# 486         487        319          102                  3  2.5   2.5  8.37
# 487         488        327          115                  4  3.5   4.0  9.14
# 488         489        322          112                  3  3.0   4.0  8.62
# 489         490        302          110                  3  4.0   4.5  8.50
# 490         491        307          105                  2  2.5   4.5  8.12
# ...

# %% [markdown]
# Dropping the 'Serial No' column.

# %%
df.drop('Serial No.', axis=1, inplace=True)
df.head()
# Out:
#    GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  Research  \
# 0        337          118                  4  4.5   4.5  9.65         1
# 1        324          107                  4  4.0   4.5  8.87         1
# 2        316          104                  3  3.0   3.5  8.00         1
# 3        322          110                  3  3.5   2.5  8.67         1
# 4        314          103                  2  2.0   3.0  8.21         0
#
#    Chance of Admit
# 0              0.92
# 1              0.76
# 2              0.72
# 3              0.80
# 4              0.65

# %% [markdown]
# Let's check for Null values.

# %%
import pandas as pd
df = pd.read_csv("Admission_Predict_Ver1.1.csv")
import pandas as pd
data = {'column1': [1, 2, 3], 'column2': [4, 5, 6]}
df = pd.DataFrame(data)

# %%
df.describe()
# Out:
#         GRE Score  TOEFL Score  University Rating         SOP       LOR   \
# count  500.000000   500.000000         500.000000  500.000000  500.00000
# mean   316.472000   107.192000           3.114000    3.374000    3.48400
# std     11.295148     6.081868           1.143512    0.991004    0.92545
# min    290.000000    92.000000           1.000000    1.000000    1.00000
# 25%    308.000000   103.000000           2.000000    2.500000    3.00000
# 50%    317.000000   107.000000           3.000000    3.500000    3.50000
# 75%    325.000000   112.000000           4.000000    4.000000    4.00000
# max    340.000000   120.000000           5.000000    5.000000    5.00000
#
#              CGPA    Research  Chance of Admit
# count  500.000000  500.000000         500.00000
# mean     8.576440    0.560000           0.72174
# std      0.604813    0.496884           0.14114
# min      6.800000    0.000000           0.34000
# 25%      8.127500    0.000000           0.63000
# ...

# %% [markdown]
# df.columns = df.columns.str.strip()
# df.columns

# %% [markdown]
# ## Individual Columns' correlation with response variable

# %%
### Column: GRE Score (out of 340)

# %%
df = pd.DataFrame(data)

# %% [markdown]
# It seems like GRE score might be a good fit. But let's dig deeper.

# %%
#import matplotlib.pyplot as plt

#plt.figure(figsize=(10, 6))
#sns.regplot(x="GRE Score", y="Chance of Admit", data=df)

# %%
from scipy import stats

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
#sns.regplot(x='GRE Score', y='Chance of Admit', data=df)

# %% [markdown]
# Since, pearson coefficient is quite near 1 and pvalue is a lot lesser than 0.001. This is an ideal predictor.

# %%
### Column: TOEFL Score (out of 120)

# %%
plt.figure(figsize=(10, 6))
sns.regplot(data=df, x='TOEFL Score', y='Chance of Admit')
# Out:
# <Axes: xlabel='TOEFL Score', ylabel='Chance of Admit'>

# %% [markdown]
# Correlation Index seems not bad. Let's dig deeper.

# %%
#from scipy import stats
import pandas as pd
df = pd.read_csv("Admission_Predict_Ver1.1.csv")
import pandas as pd
data = {'GRE Score': [320, 330, 310], 'Chance of Admit': [0.8, 0.9, 0.7]}
df = pd.DataFrame(data)

# %% [markdown]
# Since, it's pearson coefficient is almost 0.8 and pvalue is quite lesser than 0.001. This seems like an ideal candidate.

# %% [markdown]
# ### Column: University Rating (out of 5)

# %%
plt.figure(figsize=(10, 6))
sns.regplot(x=df['University Rating'], y=df['Chance of Admit'])
# Out:
# <Axes: xlabel='University Rating', ylabel='Chance of Admit'>

# %% [markdown]
# Since, university rating is out of 5, let's look at it as a categorical value.

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(data=df, x='University Rating', y='Chance of Admit')
# Out:
# <Axes: xlabel='University Rating', ylabel='Chance of Admit'>

# %%
df[['University Rating', 'Chance of Admit']].corr()
# Out:
#                    University Rating  Chance of Admit
# University Rating           1.000000         0.690132
# Chance of Admit             0.690132         1.000000

# %%
coef, pvalue = stats.pearsonr(df['University Rating'], df['Chance of Admit'])
coef, pvalue
# Out:
# (0.690132368788689, 5.866255627651306e-72)

# %% [markdown]
# Pearson Correlation seems good. And the pvalue suggests that it is not by chance. We may consider it for the ML model.
#
# Also, it appears we have a trend here. The higher the university rating, the higher the chance of admission.
# This is a good predictor of chance of admission.
# We'll consider it in training the model. Although, let's check the association between them using ANOVA too.

# %%
df_rating_grp = df[['University Rating', 'Chance of Admit']].groupby(['University Rating'])

# %%
f, pvalue = stats.f_oneway(df_rating_grp.get_group(1)['Chance of Admit'], 
                           df_rating_grp.get_group(2)['Chance of Admit'], 
                           df_rating_grp.get_group(3)['Chance of Admit'], 
                           df_rating_grp.get_group(4)['Chance of Admit'], 
                           df_rating_grp.get_group(5)['Chance of Admit'])

print('f oneway:', f, '\nP Value:', pvalue)
# Out:
# f oneway: 114.00804341400004
# P Value: 7.753395328023128e-69

# %% [markdown]
# ANOVA shows a very strong association between University Rating and Chance of Admit. We'll take it into model.

# %%
### Column: SOP or Statement of Purpose (out of 5)

# %%
plt.figure(figsize=(10, 6))
sns.regplot(data=df, x='SOP', y='Chance of Admit')
# Out:
# <Axes: xlabel='SOP', ylabel='Chance of Admit'>

# %%
df[['SOP', 'Chance of Admit']].corr()
# Out:
#                       SOP  Chance of Admit
# SOP              1.000000         0.684137
# Chance of Admit  0.684137         1.000000

# %% [markdown]
# Let's look at it from a categorical perspective.

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(data=df, x='SOP', y='Chance of Admit')
# Out:
# <Axes: xlabel='SOP', ylabel='Chance of Admit'>

# %% [markdown]
# There tends to be an increasing trend.<br>
# Let's look at the pearson correlation coefficient and ANOVA.

# %%
p_coeff, pvalue = stats.pearsonr(df.SOP, df['Chance of Admit'])

print('Pearson Coefficient: ', p_coeff)
print('P Value:             ', pvalue)
# Out:
# Pearson Coefficient:  0.6841365241316724
# P Value:              2.885907453454975e-70

# %% [markdown]
# Pearson Coefficient is not bad. Let's look at the ANOVA.

# %%
df_sop_grp = df[['SOP', 'Chance of Admit']].groupby(['SOP'])

# %%
f, pvalue = stats.f_oneway(df_sop_grp.get_group(1.0)['Chance of Admit'],
                          df_sop_grp.get_group(1.5)['Chance of Admit'],
                          df_sop_grp.get_group(2.0)['Chance of Admit'],
                          df_sop_grp.get_group(2.5)['Chance of Admit'],
                          df_sop_grp.get_group(3.0)['Chance of Admit'],
                          df_sop_grp.get_group(3.5)['Chance of Admit'],
                          df_sop_grp.get_group(4.0)['Chance of Admit'],
                          df_sop_grp.get_group(4.5)['Chance of Admit'],
                          df_sop_grp.get_group(5.0)['Chance of Admit'])

f, pvalue
# Out:
# (55.974076863949875, 2.18047357827063e-64)

# %% [markdown]
# After ANOVA, this seems like a good feature to get into model. This feature is selected.

# %%
### Column: LOR (Letter of Recommendation)

# %%
plt.figure(figsize=(10, 6))
sns.regplot(x=df.LOR, y=df['Chance of Admit'])
# Out:
# <Axes: xlabel='LOR', ylabel='Chance of Admit'>

# %%
df[['LOR', 'Chance of Admit']].corr()
# Out:
#                       LOR  Chance of Admit
# LOR              1.000000         0.645365
# Chance of Admit  0.645365         1.000000

# %%
p_coeff, pvalue = stats.pearsonr(df.LOR, df['Chance of Admit'])

p_coeff, pvalue
# Out:
# (0.6453645135280106, 3.0699323203003144e-60)

# %% [markdown]
# Let's check the ANOVA too.

# %%
df_lor_grp = df[['LOR', 'Chance of Admit']].groupby('LOR')

# %%
f, pvalue = stats.f_oneway(df_lor_grp.get_group(1.0)['Chance of Admit'],
                          df_lor_grp.get_group(1.5)['Chance of Admit'],
                          df_lor_grp.get_group(2.0)['Chance of Admit'],
                          df_lor_grp.get_group(2.5)['Chance of Admit'],
                          df_lor_grp.get_group(3.0)['Chance of Admit'],
                          df_lor_grp.get_group(3.5)['Chance of Admit'],
                          df_lor_grp.get_group(4.0)['Chance of Admit'],
                          df_lor_grp.get_group(4.5)['Chance of Admit'],
                          df_lor_grp.get_group(5.0)['Chance of Admit'])

f, pvalue
# Out:
# (44.55014196190304, 1.2475714296300813e-53)

# %% [markdown]
# ANOVA is not bad in this case. We'll consider column.

# %%
### Column: CGPA

# %%
plt.figure(figsize=(10, 6))
sns.regplot(x=df.CGPA, y=df['Chance of Admit'])
# Out:
# <Axes: xlabel='CGPA', ylabel='Chance of Admit'>

# %% [markdown]
# There appears to be quite a strong relation between CGPA and Chance of Admit.

# %%
df[['CGPA', 'Chance of Admit']].corr()
# Out:
#                      CGPA  Chance of Admit
# CGPA             1.000000         0.882413
# Chance of Admit  0.882413         1.000000

# %%
p_coeff, pvalue = stats.pearsonr(df.CGPA, df['Chance of Admit'])

p_coeff, pvalue
# Out:
# (0.8824125749045743, 3.39654485871265e-165)

# %% [markdown]
# This is a very strong predictor according to the pearson score. We'll consider to get into the model.

# %%
### Column: Research

# %%
plt.figure(figsize=(10, 6))
sns.regplot(x=df.Research, y=df['Chance of Admit'])
# Out:
# <Axes: xlabel='Research', ylabel='Chance of Admit'>

# %%
df[['Research', 'Chance of Admit']].corr()
# Out:
#                  Research  Chance of Admit
# Research         1.000000         0.545871
# Chance of Admit  0.545871         1.000000

# %% [markdown]
# Since, this is a binary variable. Let's look at it in a categorical way.

# %%
plt.figure(figsize=(5, 6))
sns.countplot(x=df.Research)
# Out:
# <Axes: xlabel='Research', ylabel='count'>

# %% [markdown]
# **Insights:** We can see that there are more candidates with research background. But without research are no less.

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x=df.Research, y=df['Chance of Admit'])
# Out:
# <Axes: xlabel='Research', ylabel='Chance of Admit'>

# %% [markdown]
# From the above box plot, we can see that the chance of admission of those having research background is more than that of those without a
# research background.

# %% [markdown]
# Let's perform ANOVA test.

# %% [markdown]
# df_res_grp = df[['Research', 'Chance of Admit']].groupby('Research')

# %%
f, pvalue = stats.f_oneway(df_res_grp.get_group(1)['Chance of Admit'],
                           df_res_grp.get_group(0)['Chance of Admit'])
f, pvalue
# Out:
# (211.37662941712796, 3.5954935458406797e-40)

# %%
## Descriptive Analytics: Analyzing predictors among themselves

# %% [markdown]
# Let's first check the heatmap of correlation of all the columns

# %%
plt.figure(figsize=(15, 6))
sns.heatmap(data=df.corr(), annot=True)
# Out:
# <Axes: >

# %% [markdown]
# Well, by looking at the heatmap, we can infer that there exists great **multicollinearity** in the data.

# %%
### GRE Score and CGPA

# %%
**Insights:** From the above plot, we can say that students with hig GRE Score tend to get higher CGPA.<br>
Comparing both with the

# %% [markdown]
# Let's compare the above plot with 'Chance of Admission'.

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x=df['GRE Score'], y=df.CGPA, hue=df['Chance of Admit'])
plt.title('Relationship between CGPA and GRE Score', fontsize=15)
plt.xlabel('GRE Score', fontsize=15)
plt.ylabel('CGPA', fontsize=15)
plt.show()

# %% [markdown]
# Chance of admission is higher for those having greater CGPA and GRE Score.

# %%
# Predicting admissions

# %% [markdown]
# First of all, let's separate the label (y) from the data (x).

# %%
X = df.drop('Chance of Admit', axis=1)
Y = df[['Chance of Admit']]

X.shape, Y.shape
# Out:
# ((500, 7), (500, 1))

# %% [markdown]
# Now, splitting the dataset into training and testing.

# %%
# Importing train_test_split
from sklearn.model_selection import train_test_split

xtrain, xtest, ytrain, ytest = train_test_split(
    X, Y, random_state=42, shuffle=True, test_size=0.30)

print(xtrain.shape, ytrain.shape)
print(xtest.shape, ytest.shape)
# Out:
# (350, 7) (350, 1)
# (150, 7) (150, 1)

# %% [markdown]
# Now, as we know that the data is highly ```multicollinear```, we are gonna try to reduce the multicollinearity using regularization.

# %%
from sklearn.linear_model import LassoCV

lasso = LassoCV(random_state=42, n_jobs=4)

lasso.fit(xtrain, ytrain)
regularized_model_prediction = lasso.predict(xtest)

# %%
from sklearn.metrics import r2_score

# %%
r2_score(ytest, regularized_model_prediction)
# Out:
# 0.8205831390252152

# %% [markdown]
# Okay, the score is not bad. How about increase the ```model complexity```.

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
list(zip(train_r2_scores, test_r2_scores))
# Out:
# [(0.817056397862837, 0.8205831390252152),
#  (0.8118252950330801, 0.8106546294010814),
#  (0.8036328552457941, 0.7983888922316117),
#  (0.7945552028478606, 0.786931798126712),
#  (0.7828994245859594, 0.7731189641603302),
#  (0.7688489667890384, 0.7571866311971951)]

# %% [markdown]
# Well, by looking at the graph above, we can select the first or second degree. But it is getting rather difficult selecting the right degree (Overfitting is difficult to recognize at this point). Now, let's check the complexity on RidgeCV (L2 Regularization).

# %%
from sklearn.linear_model import RidgeCV

# %%
# Checking the degree of polynomial from 1 to 6
train_r2_scores = []
test_r2_scores = []
for degree in range(1, 7):
    # Converting the features to polynomial
    model_poly = PolynomialFeatures(degree=degree)
    xtrain_poly, xtest_poly = model_poly.fit_transform(xtrain), model_poly.fit_transform(xtest)
    
    # Initializing LassoCV
    model_ridge = RidgeCV(cv=5)
    model_ridge.fit(xtrain_poly, ytrain)
    
    # Getting the training score in the list
    train_r2_scores.append(r2_score(ytrain, model_ridge.predict(xtrain_poly)))
    test_r2_scores.append(r2_score(ytest, model_ridge.predict(xtest_poly)))

# Displaying the model complexity
plt.figure(figsize=(10, 7))
sns.lineplot(x=range(1, 7), y=train_r2_scores, label='Training')
sns.lineplot(x=range(1, 7), y=test_r2_scores, label='Testing')
plt.xlabel('Degrees', fontsize=15)
plt.ylabel('R-Squared Coef.', fontsize=15)
plt.title('Model Complexity', fontsize=15)
plt.show()

# %%
list(zip(train_r2_scores, test_r2_scores))
# Out:
# [(0.8181067830196194, 0.8252330309714185),
#  (0.8308240346625839, 0.8332649801156904),
#  (0.8538622132046426, 0.7732757728670188),
#  (0.9308932540460203, -0.8310370562577691),
#  (-0.161993352256103, -0.5829563852105655),
#  (0.6148238294165744, 0.47937458167989344)]

# %% [markdown]
# Looking at degree 2, R-Squared Coefficient is 0.83. Seems good.

# %%
## Applying K-Nearest Neighbors Algorithm

# %%
# Importing KNN
from sklearn.neighbors import KNeighborsRegressor  # Notice here we are taking regressor because we are predicting a continuous variable

# %% [markdown]
# **```An Important thing to notice here```**<br><br>
# Since, this Algorithm is a distance based algorithm, we need to scale our data.

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()

# %%
scaled = scaler.fit_transform(X)

# %%
X = pd.DataFrame(data=scaled, columns=X.columns)
X.head()
# Out:
#    GRE Score  TOEFL Score  University Rating    SOP    LOR      CGPA  Research
# 0       0.94     0.928571               0.75  0.875  0.875  0.913462       1.0
# 1       0.68     0.535714               0.75  0.750  0.875  0.663462       1.0
# 2       0.52     0.428571               0.50  0.500  0.625  0.384615       1.0
# 3       0.64     0.642857               0.50  0.625  0.375  0.599359       1.0
# 4       0.48     0.392857               0.25  0.250  0.500  0.451923       0.0

# %% [markdown]
# Now, that our data is scaled, let's fit the model on KNN.

# %%
model_knn = KNeighborsRegressor()

# %% [markdown]
# Now, splitting the scaled data into training and testing.

# %%
xtrain, xtest, ytrain, ytest = train_test_split(
    X, Y, random_state=42, test_size=0.3, shuffle=True)

# %%
print(xtrain.shape, xtest.shape)
print(ytrain.shape, ytest.shape)
# Out:
# (350, 7) (150, 7)
# (350, 1) (150, 1)

# %% [markdown]
# Fitting the data into KNN Model.

# %%
model_knn.fit(xtrain, ytrain)
# Out:
# KNeighborsRegressor()

# %%
KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
          metric_params=None, n_jobs=None, n_neighbors=5, p=2,
          weights='uniform')
# Out:
# KNeighborsRegressor()

# %%
knn_pred_test = model_knn.predict(xtest)

# %%
knn_pred_train = model_knn.predict(xtrain)

# %%
knn_r2_train = r2_score(ytrain, knn_pred_train)
knn_r2_test = r2_score(ytest, knn_pred_test)

# %%
knn_r2_train, knn_r2_test
# Out:
# (0.8376927729408576, 0.790336806082742)

# %% [markdown]
# That result was on default neighbor size of 5. Let's now check the ```optimal number of neighbors``` of KNN.

# %%
train_r2_scores = []
test_r2_scores = []

for n in range(1, 30):
    # Initializing KNN
    model_knn = KNeighborsRegressor(n_neighbors=n)
    
    # Fitting the data and taking predictions for both training and testing dataset
    model_knn.fit(xtrain, ytrain)
    knn_pred_train, knn_pred_test = model_knn.predict(xtrain), model_knn.predict(xtest)
    
    # Storing the R-Squared Coefficient into list
    train_r2_scores.append(r2_score(ytrain, knn_pred_train))
    test_r2_scores.append(r2_score(ytest, knn_pred_test))

# %%
plt.figure(figsize=(15, 7))
sns.lineplot(x=range(1, 30), y=train_r2_scores, label='Training')
sns.lineplot(x=range(1, 30), y=test_r2_scores, label='Testing')
plt.xticks(range(1, 30))
# Out:
# ([<matplotlib.axis.XTick at 0x1aa53fd1790>,
# ...
#  [Text(1, 0, '1'),
#   Text(2, 0, '2'),
#   Text(3, 0, '3'),
#   Text(4, 0, '4'),
#   Text(5, 0, '5'),
#   Text(6, 0, '6'),
#   Text(7, 0, '7'),
#   Text(8, 0, '8'),
#   Text(9, 0, '9'),
#   Text(10, 0, '10'),
#   Text(11, 0, '11'),
#   Text(12, 0, '12'),
#   Text(13, 0, '13'),
#   Text(14, 0, '14'),
#   Text(15, 0, '15'),
#   Text(16, 0, '16'),
#   Text(17, 0, '17'),
#   Text(18, 0, '18'),
#   Text(19, 0, '19'),
#   Text(20, 0, '20'),
#   Text(21, 0, '21'),
#   Text(22, 0, '22'),
#   Text(23, 0, '23'),
#   Text(24, 0, '24'),
#   Text(25, 0, '25'),
#   Text(26, 0, '26'),
#   Text(27, 0, '27'),
#   Text(28, 0, '28'),
#   Text(29, 0, '29')])

# %% [markdown]
# So, around 11 neighbors, we can see that the training and testing score is almost the same. We can take this number of neighbors and apply some model complexity.

# %% [markdown]
# ### Model Complexity

# %% [markdown]
# Checking the degree of polynomial from 1 to 6

# %%
train_r2_scores = []
test_r2_scores = []
for degree in range(1, 7):
    # Converting the features to polynomial
    model_poly = PolynomialFeatures(degree=degree)
    xtrain_poly, xtest_poly = model_poly.fit_transform(xtrain), model_poly.fit_transform(xtest)
    
    # Initializing KNN
    model_knn = KNeighborsRegressor(n_neighbors=11)
    model_knn.fit(xtrain_poly, ytrain)
    
    # Getting the training score in the list
    train_r2_scores.append(r2_score(ytrain, model_knn.predict(xtrain_poly)))
    test_r2_scores.append(r2_score(ytest, model_knn.predict(xtest_poly)))

# Displaying the model complexity
plt.figure(figsize=(10, 7))
sns.lineplot(x=range(1, 7), y=train_r2_scores, label='Training')
sns.lineplot(x=range(1, 7), y=test_r2_scores, label='Testing')
plt.xlabel('Degrees', fontsize=15)
plt.ylabel('R-Squared Coef.', fontsize=15)
plt.title('Model Complexity', fontsize=15)
plt.yticks([0.7, 0.72, 0.74, 0.76, 0.78, 0.8, 0.82])
plt.show()

# %%
list(zip(train_r2_scores, test_r2_scores))
# Out:
# [(0.7900288630493129, 0.793831571905104),
#  (0.8010992844320545, 0.7962334746307963),
#  (0.8026090087473935, 0.7985999541817976),
#  (0.8015539255997084, 0.7973474541692145),
#  (0.8031157303051473, 0.8001297594947607),
#  (0.8019861078578788, 0.8003351610375588)]
